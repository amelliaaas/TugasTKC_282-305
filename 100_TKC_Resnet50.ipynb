# %% [markdown]
# <a href="https://colab.research.google.com/github/amelliaaas/TugasTKC_282-305/blob/main/100_TKC_Resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/COVID-19_Radiography/dataset
# Out:
# /content/drive/MyDrive/COVID-19_Radiography/dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras

import os
import random
import cv2
from tqdm import tqdm

# %%
labels = ['Covid', 'Normal', 'Viral Pneumonia']
IMG_SIZE = 124

# %%
# load all the images
def loadData(DIR):
    X = []
    Y = []
    for label in labels:
        path = os.path.join(DIR, label)
        class_num = labels.index(label)
        for img in tqdm(os.listdir(path)):
            try:
                arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(arr, (IMG_SIZE, IMG_SIZE))
                X.append(resized_arr)
                Y.append(class_num)
            except Exception as e:
                print(e)
    return (np.array(X), np.array(Y))

# %%
DIR = '/content/drive/MyDrive/COVID-19_Radiography/dataset'
(X, Y) = loadData(DIR)
# Out:
# 100%|██████████| 219/219 [00:02<00:00, 99.81it/s]
# 100%|██████████| 1341/1341 [00:23<00:00, 56.18it/s]
# 100%|██████████| 1350/1350 [00:18<00:00, 74.16it/s]

# %% [markdown]
# ## Visualisasi Data

# %%
l = []
for img in Y:
    l.append(labels[img])
sns.countplot(l);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax = plt.subplots(3)
fig.set_size_inches(15, 20)
for i in range(3):
        l = random.randint(0, len(X))
        ax[i].imshow(X[l])
        ax[i].set_title('Image: ' + labels[Y[l]])

# %% [markdown]
# ## Preprocessing data

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# normalize the data
X = X / 255

# reshape the data
X = X.reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y = Y.reshape(-1, 1)
Y = keras.utils.to_categorical(Y, 3)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# Explore the dataset
print("X_train shape:" + str(X_train.shape))
print("Y_train shape:" + str(Y_train.shape))
print("X_test shape:" + str(X_test.shape))
print("Y_test shape:" + str(Y_test.shape))
# Out:
# X_train shape:(2037, 124, 124, 3)
# Y_train shape:(2037, 3)
# X_test shape:(873, 124, 124, 3)
# Y_test shape:(873, 3)

# %% [markdown]
# # Modelling

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten,BatchNormalization
from keras.layers import Dense

# %%
from tensorflow.keras.applications import ResNet50

# %%
pre_trained_model = ResNet50(input_shape = (IMG_SIZE, IMG_SIZE, 3), include_top = False, weights = 'imagenet')


model1 = Sequential(
    [
        pre_trained_model,
        Flatten(),
        Dense(3, activation = 'softmax')
    ]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 3)                 98307
#
# =================================================================
# Total params: 23,686,019
# Trainable params: 23,632,899
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model1.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history1 = model1.fit(X_train, Y_train, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 51/51 [==============================] - 25s 181ms/step - loss: 0.9882 - accuracy: 0.8594 - val_loss: 37090.5430 - val_accuracy: 0.4681
# Epoch 2/100
# 51/51 [==============================] - 7s 130ms/step - loss: 0.1634 - accuracy: 0.9411 - val_loss: 1.0779 - val_accuracy: 0.4559
# Epoch 3/100
# 51/51 [==============================] - 7s 130ms/step - loss: 0.0632 - accuracy: 0.9773 - val_loss: 1.1563 - val_accuracy: 0.4559
# Epoch 4/100
# 51/51 [==============================] - 7s 131ms/step - loss: 0.0386 - accuracy: 0.9828 - val_loss: 1.1791 - val_accuracy: 0.4559
# Epoch 5/100
# 51/51 [==============================] - 7s 131ms/step - loss: 0.0161 - accuracy: 0.9957 - val_loss: 1.1521 - val_accuracy: 0.4559
# Epoch 6/100
# 51/51 [==============================] - 7s 134ms/step - loss: 0.0788 - accuracy: 0.9742 - val_loss: 1.2224 - val_accuracy: 0.4559
# Epoch 7/100
# 51/51 [==============================] - 7s 132ms/step - loss: 0.0356 - accuracy: 0.9896 - val_loss: 1.5733 - val_accuracy: 0.4559
# Epoch 8/100
# 51/51 [==============================] - 7s 132ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 2.7980 - val_accuracy: 0.0760
# Epoch 9/100
# 51/51 [==============================] - 7s 133ms/step - loss: 0.0068 - accuracy: 0.9969 - val_loss: 2.6450 - val_accuracy: 0.0760
# Epoch 10/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0195 - accuracy: 0.9945 - val_loss: 2.9299 - val_accuracy: 0.0760
# Epoch 11/100
# 51/51 [==============================] - 7s 135ms/step - loss: 0.1015 - accuracy: 0.9718 - val_loss: 1.2283 - val_accuracy: 0.0760
# Epoch 12/100
# 51/51 [==============================] - 7s 135ms/step - loss: 0.0377 - accuracy: 0.9871 - val_loss: 1.7559 - val_accuracy: 0.0760
# Epoch 13/100
# 51/51 [==============================] - 7s 136ms/step - loss: 5.4154 - accuracy: 0.8146 - val_loss: 616723212402688.0000 - val_accuracy: 0.4559
# Epoch 14/100
# 51/51 [==============================] - 7s 137ms/step - loss: 1.5279 - accuracy: 0.7182 - val_loss: 14399898.0000 - val_accuracy: 0.4559
# Epoch 15/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.1524 - accuracy: 0.7766 - val_loss: 10477.7852 - val_accuracy: 0.4559
# Epoch 16/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.8904 - accuracy: 0.8263 - val_loss: 523.6672 - val_accuracy: 0.4853
# Epoch 17/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.4654 - accuracy: 0.8815 - val_loss: 2.0027 - val_accuracy: 0.5319
# Epoch 18/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.3136 - accuracy: 0.8870 - val_loss: 0.7961 - val_accuracy: 0.6863
# Epoch 19/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.2416 - accuracy: 0.9085 - val_loss: 0.4082 - val_accuracy: 0.8358
# Epoch 20/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.2516 - accuracy: 0.9190 - val_loss: 0.3302 - val_accuracy: 0.8995
# Epoch 21/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.2976 - accuracy: 0.9134 - val_loss: 3.3648 - val_accuracy: 0.6495
# Epoch 22/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.2622 - accuracy: 0.9171 - val_loss: 0.3933 - val_accuracy: 0.8529
# Epoch 23/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.1852 - accuracy: 0.9343 - val_loss: 0.3863 - val_accuracy: 0.8848
# Epoch 24/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.2051 - accuracy: 0.9306 - val_loss: 0.2987 - val_accuracy: 0.9044
# Epoch 25/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.1455 - accuracy: 0.9460 - val_loss: 0.2979 - val_accuracy: 0.8922
# Epoch 26/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.1438 - accuracy: 0.9435 - val_loss: 0.3174 - val_accuracy: 0.8971
# Epoch 27/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.1256 - accuracy: 0.9490 - val_loss: 0.2803 - val_accuracy: 0.9093
# Epoch 28/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.1109 - accuracy: 0.9644 - val_loss: 0.3283 - val_accuracy: 0.8799
# Epoch 29/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.1046 - accuracy: 0.9607 - val_loss: 0.3065 - val_accuracy: 0.9069
# Epoch 30/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.1102 - accuracy: 0.9626 - val_loss: 0.8588 - val_accuracy: 0.8382
# Epoch 31/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.1469 - accuracy: 0.9484 - val_loss: 0.3180 - val_accuracy: 0.8946
# Epoch 32/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.1836 - accuracy: 0.9595 - val_loss: 0.4594 - val_accuracy: 0.8284
# Epoch 33/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0939 - accuracy: 0.9669 - val_loss: 0.4090 - val_accuracy: 0.8652
# Epoch 34/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0668 - accuracy: 0.9767 - val_loss: 0.3154 - val_accuracy: 0.9069
# Epoch 35/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.1073 - accuracy: 0.9669 - val_loss: 0.4156 - val_accuracy: 0.8799
# Epoch 36/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.2370 - accuracy: 0.9711 - val_loss: 0.2796 - val_accuracy: 0.9093
# Epoch 37/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.1915 - accuracy: 0.9411 - val_loss: 0.3969 - val_accuracy: 0.8603
# Epoch 38/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.2120 - accuracy: 0.9626 - val_loss: 0.4586 - val_accuracy: 0.8358
# Epoch 39/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.1240 - accuracy: 0.9576 - val_loss: 0.5392 - val_accuracy: 0.8358
# Epoch 40/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0782 - accuracy: 0.9662 - val_loss: 0.4474 - val_accuracy: 0.8652
# Epoch 41/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.1064 - accuracy: 0.9834 - val_loss: 0.4519 - val_accuracy: 0.8480
# Epoch 42/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.2271 - accuracy: 0.9804 - val_loss: 0.7086 - val_accuracy: 0.8064
# Epoch 43/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.1929 - accuracy: 0.9355 - val_loss: 0.8630 - val_accuracy: 0.7549
# Epoch 44/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.1702 - accuracy: 0.9435 - val_loss: 1.6821 - val_accuracy: 0.7696
# Epoch 45/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.2669 - accuracy: 0.9509 - val_loss: 1.2742 - val_accuracy: 0.6789
# Epoch 46/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.3294 - accuracy: 0.9171 - val_loss: 32.0772 - val_accuracy: 0.5025
# Epoch 47/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.2258 - accuracy: 0.9276 - val_loss: 5.5972 - val_accuracy: 0.7966
# Epoch 48/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.1323 - accuracy: 0.9515 - val_loss: 1.9784 - val_accuracy: 0.8260
# Epoch 49/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0821 - accuracy: 0.9675 - val_loss: 0.3287 - val_accuracy: 0.9069
# Epoch 50/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0520 - accuracy: 0.9847 - val_loss: 0.5532 - val_accuracy: 0.9142
# Epoch 51/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0398 - accuracy: 0.9877 - val_loss: 0.3680 - val_accuracy: 0.8995
# Epoch 52/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.0427 - accuracy: 0.9859 - val_loss: 0.3981 - val_accuracy: 0.8873
# Epoch 53/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0362 - accuracy: 0.9871 - val_loss: 0.3751 - val_accuracy: 0.9044
# Epoch 54/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 0.3815 - val_accuracy: 0.9093
# Epoch 55/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0243 - accuracy: 0.9914 - val_loss: 0.4595 - val_accuracy: 0.8971
# Epoch 56/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0140 - accuracy: 0.9975 - val_loss: 0.3984 - val_accuracy: 0.9142
# Epoch 57/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0168 - accuracy: 0.9957 - val_loss: 0.5348 - val_accuracy: 0.9020
# Epoch 58/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 0.6307 - val_accuracy: 0.8848
# Epoch 59/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0272 - accuracy: 0.9908 - val_loss: 0.5097 - val_accuracy: 0.8946
# Epoch 60/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0340 - accuracy: 0.9896 - val_loss: 0.6209 - val_accuracy: 0.8873
# Epoch 61/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0229 - accuracy: 0.9914 - val_loss: 0.4582 - val_accuracy: 0.8995
# Epoch 62/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.4112 - val_accuracy: 0.9020
# Epoch 63/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0066 - accuracy: 0.9988 - val_loss: 0.4386 - val_accuracy: 0.8971
# Epoch 64/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.4408 - val_accuracy: 0.8971
# Epoch 65/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.5199 - val_accuracy: 0.9069
# Epoch 66/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0065 - accuracy: 0.9988 - val_loss: 0.4520 - val_accuracy: 0.8995
# Epoch 67/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 0.4651 - val_accuracy: 0.9044
# Epoch 68/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.4649 - val_accuracy: 0.8995
# Epoch 69/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.9069
# Epoch 70/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.4715 - val_accuracy: 0.9069
# Epoch 71/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.4997 - val_accuracy: 0.9093
# Epoch 72/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.5003 - val_accuracy: 0.9044
# Epoch 73/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0076 - accuracy: 0.9988 - val_loss: 0.4739 - val_accuracy: 0.9142
# Epoch 74/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.5138 - val_accuracy: 0.9118
# Epoch 75/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0467 - accuracy: 0.9822 - val_loss: 0.8283 - val_accuracy: 0.8652
# Epoch 76/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0276 - accuracy: 0.9896 - val_loss: 0.4383 - val_accuracy: 0.9142
# Epoch 77/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0345 - accuracy: 0.9896 - val_loss: 0.5421 - val_accuracy: 0.9093
# Epoch 78/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0232 - accuracy: 0.9945 - val_loss: 0.5649 - val_accuracy: 0.9142
# Epoch 79/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0142 - accuracy: 0.9963 - val_loss: 0.4770 - val_accuracy: 0.9069
# Epoch 80/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.4735 - val_accuracy: 0.9020
# Epoch 81/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0061 - accuracy: 0.9988 - val_loss: 0.5155 - val_accuracy: 0.9118
# Epoch 82/100
# 51/51 [==============================] - 7s 138ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.5267 - val_accuracy: 0.9118
# Epoch 83/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.5391 - val_accuracy: 0.9216
# Epoch 84/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.6497 - val_accuracy: 0.8995
# Epoch 85/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0061 - accuracy: 0.9994 - val_loss: 0.6648 - val_accuracy: 0.8897
# Epoch 86/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 0.5515 - val_accuracy: 0.9167
# Epoch 87/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.4871 - val_accuracy: 0.9265
# Epoch 88/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 2.2898 - val_accuracy: 0.7843
# Epoch 89/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.6276 - val_accuracy: 0.8897
# Epoch 90/100
# 51/51 [==============================] - 7s 136ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 1.1516 - val_accuracy: 0.8186
# Epoch 91/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0138 - accuracy: 0.9963 - val_loss: 0.6705 - val_accuracy: 0.9093
# Epoch 92/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 0.8731 - val_accuracy: 0.8922
# Epoch 93/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.5441 - val_accuracy: 0.9265
# Epoch 94/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.6018 - val_accuracy: 0.9191
# Epoch 95/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 2.1231 - val_accuracy: 0.8333
# Epoch 96/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6185 - val_accuracy: 0.9142
# Epoch 97/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.5803 - val_accuracy: 0.9289
# Epoch 98/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0063 - accuracy: 0.9988 - val_loss: 0.5398 - val_accuracy: 0.9338
# Epoch 99/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.7302 - val_accuracy: 0.8873
# Epoch 100/100
# 51/51 [==============================] - 7s 137ms/step - loss: 0.0055 - accuracy: 0.9975 - val_loss: 0.5455 - val_accuracy: 0.9216

# %%
# plot training and validation accuracy values
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# plot training and validation loss values
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
Y_pred = model1.predict(X_test)
Y_pred = np.argmax(Y_pred, axis = 1)
Y_test = np.argmax(Y_test, axis = 1)

# get the correctly and incorrectly labelled images
correct = np.nonzero(Y_pred == Y_test)[0]
incorrect = np.nonzero(Y_pred != Y_test)[0]

print("correct shape:" + str(correct.shape))
print("incorrect shape:" + str(incorrect.shape))

# Classification Report
print(classification_report(Y_test, Y_pred))
# Out:
# correct shape:(810,)
# incorrect shape:(63,)
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89        63
#            1       0.94      0.93      0.93       416
#            2       0.92      0.94      0.93       394
#
#     accuracy                           0.93       873
#    macro avg       0.92      0.91      0.92       873
# weighted avg       0.93      0.93      0.93       873

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(Y_test, Y_pred), annot=True, fmt=".0f", ax=ax)
plt.xlabel("y_head")
plt.ylabel("y_true")
plt.show()

# %%
#save model.h5
model1.save('model_resnet3_tkc.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
# !pip install pyyaml h5py
model_json = model1.to_json()
with open("model_resnet2_tkc.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model1.save_weights("model_resnet2_tkc.hdf5")
print("Saved model to disk")
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Saved model to disk

# %%
# subset of correcly predicted images
fig, ax = plt.subplots(3, 2)
fig.set_size_inches(12, 16)
cur = 0
for i in range(3):
    for j in range(2):
        ax[i, j].imshow(X_test[correct[cur]])
        ax[i, j].set_title("Predicted {}\nActual {}".format(labels[Y_pred[correct[cur]]], labels[Y_test[correct[cur]]]))
        cur = cur + 1

# %%
# subset of incorrecly predicted images
fig, ax = plt.subplots(3, 2)
fig.set_size_inches(12, 16)
cur = 0
for i in range(3):
    for j in range(2):
        ax[i, j].imshow(X_test[incorrect[cur]])
        ax[i, j].set_title("Predicted {}\nActual {}".format(labels[Y_pred[incorrect[cur]]], labels[Y_test[incorrect[cur]]]))
        cur = cur + 1

# %% [markdown]
# **Note : **
#
# 1. Jumlah Cell Classification Report 1 notebook hanya bisa 1 cell. Sehingga, jika dibutuhkan classification report dr model yg lain harus running dari awal.
# 2. Berkaitan dengan poin 1, dipilih akurasi tertinggi dari ketiga model. Sehingga, yg ditampilkan Classification Report hanya untuk akurasi tertinggi "Model Ketiga dengan VGG16)
