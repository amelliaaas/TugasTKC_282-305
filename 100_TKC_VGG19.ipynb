# %% [markdown]
# <a href="https://colab.research.google.com/github/amelliaaas/TugasTKC_282-305/blob/main/100_TKC_VGG19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/COVID-19_Radiography/dataset
# Out:
# /content/drive/MyDrive/COVID-19_Radiography/dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras

import os
import random
import cv2
from tqdm import tqdm

# %%
labels = ['Covid', 'Normal', 'Viral Pneumonia']
IMG_SIZE = 124

# %%
# load all the images
def loadData(DIR):
    X = []
    Y = []
    for label in labels:
        path = os.path.join(DIR, label)
        class_num = labels.index(label)
        for img in tqdm(os.listdir(path)):
            try:
                arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(arr, (IMG_SIZE, IMG_SIZE))
                X.append(resized_arr)
                Y.append(class_num)
            except Exception as e:
                print(e)
    return (np.array(X), np.array(Y))

# %%
DIR = '/content/drive/MyDrive/COVID-19_Radiography/dataset'
(X, Y) = loadData(DIR)
# Out:
# 100%|██████████| 219/219 [00:02<00:00, 73.13it/s]
# 100%|██████████| 1341/1341 [00:21<00:00, 61.44it/s]
# 100%|██████████| 1350/1350 [00:21<00:00, 62.43it/s]

# %% [markdown]
# ## Visualisasi Data

# %%
l = []
for img in Y:
    l.append(labels[img])
sns.countplot(l);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax = plt.subplots(3)
fig.set_size_inches(15, 20)
for i in range(3):
        l = random.randint(0, len(X))
        ax[i].imshow(X[l])
        ax[i].set_title('Image: ' + labels[Y[l]])

# %% [markdown]
# ## Preprocessing data

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# normalize the data
X = X / 255

# reshape the data
X = X.reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y = Y.reshape(-1, 1)
Y = keras.utils.to_categorical(Y, 3)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# Explore the dataset
print("X_train shape:" + str(X_train.shape))
print("Y_train shape:" + str(Y_train.shape))
print("X_test shape:" + str(X_test.shape))
print("Y_test shape:" + str(Y_test.shape))
# Out:
# X_train shape:(2037, 124, 124, 3)
# Y_train shape:(2037, 3)
# X_test shape:(873, 124, 124, 3)
# Y_test shape:(873, 3)

# %% [markdown]
# # Modelling

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten,BatchNormalization
from keras.layers import Dense

# %%
from tensorflow.keras.applications import VGG19

# %%
pre_trained_model = VGG19(input_shape = (IMG_SIZE, IMG_SIZE, 3), include_top = False, weights = 'imagenet')

for layer in pre_trained_model.layers[:19]:
    layer.trainable = False

model1 = Sequential(
    [
        pre_trained_model,
        Flatten(),
        Dense(3, activation = 'softmax')
    ]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 3, 3, 512)         20024384
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 3)                 13827
#
# =================================================================
# Total params: 20,038,211
# Trainable params: 4,733,443
# Non-trainable params: 15,304,768
# _________________________________________________________________

# %%
model1.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history1 = model1.fit(X_train, Y_train, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 51/51 [==============================] - 26s 267ms/step - loss: 0.5289 - accuracy: 0.8214 - val_loss: 0.1971 - val_accuracy: 0.9461
# Epoch 2/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.1645 - accuracy: 0.9423 - val_loss: 0.1231 - val_accuracy: 0.9632
# Epoch 3/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.1232 - accuracy: 0.9576 - val_loss: 0.1124 - val_accuracy: 0.9706
# Epoch 4/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0828 - accuracy: 0.9675 - val_loss: 0.1047 - val_accuracy: 0.9681
# Epoch 5/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0636 - accuracy: 0.9761 - val_loss: 0.1309 - val_accuracy: 0.9461
# Epoch 6/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0497 - accuracy: 0.9828 - val_loss: 0.1500 - val_accuracy: 0.9485
# Epoch 7/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0367 - accuracy: 0.9859 - val_loss: 0.0863 - val_accuracy: 0.9755
# Epoch 8/100
# 51/51 [==============================] - 7s 140ms/step - loss: 0.0231 - accuracy: 0.9908 - val_loss: 0.0924 - val_accuracy: 0.9804
# Epoch 9/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.0974 - val_accuracy: 0.9755
# Epoch 10/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.1035 - val_accuracy: 0.9755
# Epoch 11/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9804
# Epoch 12/100
# 51/51 [==============================] - 7s 139ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1091 - val_accuracy: 0.9779
# Epoch 13/100
# 51/51 [==============================] - 7s 139ms/step - loss: 4.3352e-04 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9779
# Epoch 14/100
# 51/51 [==============================] - 7s 139ms/step - loss: 3.2827e-04 - accuracy: 1.0000 - val_loss: 0.1080 - val_accuracy: 0.9804
# Epoch 15/100
# 51/51 [==============================] - 7s 139ms/step - loss: 2.2915e-04 - accuracy: 1.0000 - val_loss: 0.1140 - val_accuracy: 0.9804
# Epoch 16/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.9512e-04 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 0.9828
# Epoch 17/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.6807e-04 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9804
# Epoch 18/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.5269e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9828
# Epoch 19/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.2711e-04 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9804
# Epoch 20/100
# 51/51 [==============================] - 7s 138ms/step - loss: 1.1258e-04 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9804
# Epoch 21/100
# 51/51 [==============================] - 7s 139ms/step - loss: 9.9633e-05 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9804
# Epoch 22/100
# 51/51 [==============================] - 7s 139ms/step - loss: 8.8231e-05 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9779
# Epoch 23/100
# 51/51 [==============================] - 7s 139ms/step - loss: 8.1337e-05 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9779
# Epoch 24/100
# 51/51 [==============================] - 7s 139ms/step - loss: 7.1279e-05 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9779
# Epoch 25/100
# 51/51 [==============================] - 7s 139ms/step - loss: 6.5993e-05 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9779
# Epoch 26/100
# 51/51 [==============================] - 7s 142ms/step - loss: 5.8195e-05 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9779
# Epoch 27/100
# 51/51 [==============================] - 7s 139ms/step - loss: 5.3222e-05 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9779
# Epoch 28/100
# 51/51 [==============================] - 7s 140ms/step - loss: 4.8194e-05 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9779
# Epoch 29/100
# 51/51 [==============================] - 7s 140ms/step - loss: 4.5366e-05 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9804
# Epoch 30/100
# 51/51 [==============================] - 7s 140ms/step - loss: 4.0693e-05 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9779
# Epoch 31/100
# 51/51 [==============================] - 7s 139ms/step - loss: 3.7621e-05 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9804
# Epoch 32/100
# 51/51 [==============================] - 7s 140ms/step - loss: 3.4680e-05 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9779
# Epoch 33/100
# 51/51 [==============================] - 7s 139ms/step - loss: 3.1871e-05 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9779
# Epoch 34/100
# 51/51 [==============================] - 7s 139ms/step - loss: 2.9194e-05 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9779
# Epoch 35/100
# 51/51 [==============================] - 7s 140ms/step - loss: 2.6786e-05 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9755
# Epoch 36/100
# 51/51 [==============================] - 7s 139ms/step - loss: 2.4578e-05 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9755
# Epoch 37/100
# 51/51 [==============================] - 7s 139ms/step - loss: 2.2716e-05 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9755
# Epoch 38/100
# 51/51 [==============================] - 7s 140ms/step - loss: 2.1304e-05 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9755
# Epoch 39/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.9510e-05 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9755
# Epoch 40/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.8009e-05 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9755
# Epoch 41/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.6741e-05 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9755
# Epoch 42/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.5433e-05 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9755
# Epoch 43/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.4680e-05 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9755
# Epoch 44/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.3392e-05 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9755
# Epoch 45/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.2595e-05 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9755
# Epoch 46/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.1712e-05 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9755
# Epoch 47/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.0923e-05 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9755
# Epoch 48/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.0359e-05 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9755
# Epoch 49/100
# 51/51 [==============================] - 7s 139ms/step - loss: 9.5157e-06 - accuracy: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.9755
# Epoch 50/100
# 51/51 [==============================] - 7s 140ms/step - loss: 9.0281e-06 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.9755
# Epoch 51/100
# 51/51 [==============================] - 7s 140ms/step - loss: 8.4570e-06 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9755
# Epoch 52/100
# 51/51 [==============================] - 7s 140ms/step - loss: 7.9806e-06 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.9755
# Epoch 53/100
# 51/51 [==============================] - 7s 139ms/step - loss: 7.4458e-06 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9779
# Epoch 54/100
# 51/51 [==============================] - 7s 139ms/step - loss: 6.9551e-06 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9755
# Epoch 55/100
# 51/51 [==============================] - 7s 140ms/step - loss: 6.4772e-06 - accuracy: 1.0000 - val_loss: 0.1639 - val_accuracy: 0.9779
# Epoch 56/100
# 51/51 [==============================] - 7s 139ms/step - loss: 6.0249e-06 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9730
# Epoch 57/100
# 51/51 [==============================] - 7s 140ms/step - loss: 5.1942e-06 - accuracy: 1.0000 - val_loss: 0.1702 - val_accuracy: 0.9730
# Epoch 58/100
# 51/51 [==============================] - 7s 140ms/step - loss: 4.4391e-06 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9706
# Epoch 59/100
# 51/51 [==============================] - 7s 140ms/step - loss: 3.9882e-06 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9755
# Epoch 60/100
# 51/51 [==============================] - 7s 140ms/step - loss: 3.2321e-06 - accuracy: 1.0000 - val_loss: 0.1786 - val_accuracy: 0.9706
# Epoch 61/100
# 51/51 [==============================] - 7s 139ms/step - loss: 2.7736e-06 - accuracy: 1.0000 - val_loss: 0.1809 - val_accuracy: 0.9706
# Epoch 62/100
# 51/51 [==============================] - 7s 139ms/step - loss: 2.3322e-06 - accuracy: 1.0000 - val_loss: 0.1820 - val_accuracy: 0.9706
# Epoch 63/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.9907e-06 - accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9730
# Epoch 64/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.8166e-06 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9730
# Epoch 65/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.5460e-06 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9730
# Epoch 66/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.3414e-06 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9730
# Epoch 67/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.1744e-06 - accuracy: 1.0000 - val_loss: 0.1952 - val_accuracy: 0.9730
# Epoch 68/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.0915e-06 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9730
# Epoch 69/100
# 51/51 [==============================] - 7s 139ms/step - loss: 9.5571e-07 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9755
# Epoch 70/100
# 51/51 [==============================] - 7s 139ms/step - loss: 8.3402e-07 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9730
# Epoch 71/100
# 51/51 [==============================] - 7s 140ms/step - loss: 7.4598e-07 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9730
# Epoch 72/100
# 51/51 [==============================] - 7s 140ms/step - loss: 6.9469e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9730
# Epoch 73/100
# 51/51 [==============================] - 7s 141ms/step - loss: 6.1917e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9730
# Epoch 74/100
# 51/51 [==============================] - 7s 140ms/step - loss: 5.6487e-07 - accuracy: 1.0000 - val_loss: 0.2140 - val_accuracy: 0.9730
# Epoch 75/100
# 51/51 [==============================] - 7s 140ms/step - loss: 5.1306e-07 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9755
# Epoch 76/100
# 51/51 [==============================] - 7s 141ms/step - loss: 4.8071e-07 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9755
# Epoch 77/100
# 51/51 [==============================] - 7s 140ms/step - loss: 4.3783e-07 - accuracy: 1.0000 - val_loss: 0.2176 - val_accuracy: 0.9730
# Epoch 78/100
# 51/51 [==============================] - 7s 140ms/step - loss: 4.0673e-07 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9730
# Epoch 79/100
# 51/51 [==============================] - 7s 139ms/step - loss: 3.6794e-07 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9730
# Epoch 80/100
# 51/51 [==============================] - 7s 139ms/step - loss: 3.4731e-07 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9755
# Epoch 81/100
# 51/51 [==============================] - 7s 139ms/step - loss: 3.1840e-07 - accuracy: 1.0000 - val_loss: 0.2238 - val_accuracy: 0.9755
# Epoch 82/100
# 51/51 [==============================] - 7s 140ms/step - loss: 2.9755e-07 - accuracy: 1.0000 - val_loss: 0.2253 - val_accuracy: 0.9755
# Epoch 83/100
# 51/51 [==============================] - 7s 140ms/step - loss: 2.7698e-07 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9730
# Epoch 84/100
# 51/51 [==============================] - 7s 140ms/step - loss: 2.6725e-07 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9755
# Epoch 85/100
# 51/51 [==============================] - 7s 139ms/step - loss: 2.4947e-07 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9755
# Epoch 86/100
# 51/51 [==============================] - 7s 139ms/step - loss: 2.3095e-07 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9755
# Epoch 87/100
# 51/51 [==============================] - 7s 140ms/step - loss: 2.1515e-07 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9755
# Epoch 88/100
# 51/51 [==============================] - 7s 140ms/step - loss: 2.0117e-07 - accuracy: 1.0000 - val_loss: 0.2348 - val_accuracy: 0.9755
# Epoch 89/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.9027e-07 - accuracy: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.9755
# Epoch 90/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.7797e-07 - accuracy: 1.0000 - val_loss: 0.2372 - val_accuracy: 0.9779
# Epoch 91/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.6429e-07 - accuracy: 1.0000 - val_loss: 0.2389 - val_accuracy: 0.9755
# Epoch 92/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.5609e-07 - accuracy: 1.0000 - val_loss: 0.2408 - val_accuracy: 0.9755
# Epoch 93/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.4899e-07 - accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9779
# Epoch 94/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.3992e-07 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.9779
# Epoch 95/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.3414e-07 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9755
# Epoch 96/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.2389e-07 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9779
# Epoch 97/100
# 51/51 [==============================] - 7s 140ms/step - loss: 1.1716e-07 - accuracy: 1.0000 - val_loss: 0.2463 - val_accuracy: 0.9755
# Epoch 98/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.1087e-07 - accuracy: 1.0000 - val_loss: 0.2484 - val_accuracy: 0.9755
# Epoch 99/100
# 51/51 [==============================] - 7s 139ms/step - loss: 1.0750e-07 - accuracy: 1.0000 - val_loss: 0.2477 - val_accuracy: 0.9755
# Epoch 100/100
# 51/51 [==============================] - 7s 141ms/step - loss: 9.9231e-08 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9755

# %%
# plot training and validation accuracy values
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# plot training and validation loss values
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
Y_pred = model1.predict(X_test)
Y_pred = np.argmax(Y_pred, axis = 1)
Y_test = np.argmax(Y_test, axis = 1)

# get the correctly and incorrectly labelled images
correct = np.nonzero(Y_pred == Y_test)[0]
incorrect = np.nonzero(Y_pred != Y_test)[0]

print("correct shape:" + str(correct.shape))
print("incorrect shape:" + str(incorrect.shape))

# Classification Report
print(classification_report(Y_test, Y_pred))
# Out:
# correct shape:(839,)
# incorrect shape:(34,)
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86        62
#            1       0.96      0.97      0.97       423
#            2       0.98      0.96      0.97       388
#
#     accuracy                           0.96       873
#    macro avg       0.93      0.94      0.93       873
# weighted avg       0.96      0.96      0.96       873

# %%
# subset of correcly predicted images
fig, ax = plt.subplots(3, 2)
fig.set_size_inches(12, 16)
cur = 0
for i in range(3):
    for j in range(2):
        ax[i, j].imshow(X_test[correct[cur]])
        ax[i, j].set_title("Predicted {}\nActual {}".format(labels[Y_pred[correct[cur]]], labels[Y_test[correct[cur]]]))
        cur = cur + 1

# %%
# subset of incorrecly predicted images
fig, ax = plt.subplots(3, 2)
fig.set_size_inches(12, 16)
cur = 0
for i in range(3):
    for j in range(2):
        ax[i, j].imshow(X_test[incorrect[cur]])
        ax[i, j].set_title("Predicted {}\nActual {}".format(labels[Y_pred[incorrect[cur]]], labels[Y_test[incorrect[cur]]]))
        cur = cur + 1

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(Y_test, Y_pred), annot=True, fmt=".0f", ax=ax)
plt.xlabel("y_head")
plt.ylabel("y_true")
plt.show()

# %%
#save model.h5
model1.save('model_vgg2_tkc.h5')

# %%
# !pip install pyyaml h5py
model_json = model1.to_json()
with open("model_vgg2_tkc.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model1.save_weights("model_vgg2_tkc.hdf5")
print("Saved model to disk")
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# Saved model to disk

# %% [markdown]
# **Note : **
#
# 1. Jumlah Cell Classification Report 1 notebook hanya bisa 1 cell. Sehingga, jika dibutuhkan classification report dr model yg lain harus running dari awal.
# 2. Berkaitan dengan poin 1, dipilih akurasi tertinggi dari ketiga model. Sehingga, yg ditampilkan Classification Report hanya untuk akurasi tertinggi "Model Ketiga dengan VGG16)
